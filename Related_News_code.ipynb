# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
input_news = """
    Wuhan's coronavirus can be cured by one bowl of freshly boiled garlic water.
"""

# %%
import requests
from bs4 import BeautifulSoup as soup
# !pip install rake_nltk
from rake_nltk import Rake
# Out:
# Collecting rake_nltk
#   Downloading https://files.pythonhosted.org/packages/8e/c4/b4ff57e541ac5624ad4b20b89c2bafd4e98f29fd83139f3a81858bdb3815/rake_nltk-1.0.4.tar.gz
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rake_nltk) (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->rake_nltk) (1.15.0)
# Building wheels for collected packages: rake-nltk
#   Building wheel for rake-nltk (setup.py) ... done
#   Created wheel for rake-nltk: filename=rake_nltk-1.0.4-py2.py3-none-any.whl size=7819 sha256=8e2ff8477f950c329d878438b97f3c5745947906a9c0befa6b2480dbcb7ff816
#   Stored in directory: /root/.cache/pip/wheels/ef/92/fc/271b3709e71a96ffe934b27818946b795ac6b9b8ff8682483f
# Successfully built rake-nltk
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.4

# %%
r = Rake()
r.extract_keywords_from_text(input_news)
keywords = r.get_ranked_phrases()[:5]
query = " "
query = query.join(keywords)

# %%
print(query)
# Out:
# freshly boiled garlic water one bowl wuhan cured coronavirus

# %%
url = "https://news.google.com/search?q=" + query
res = requests.get(url)

# %%
soup = soup(res.content)
all_news = soup.findAll('div', {'class' : 'NiLAwe y6IFtc R7GTQ keNKEd j7vNaf nID9nc'})

# %%
related_news = []
for news in all_news:
    temp = {}
    temp['title'] = news.find('h3').find('a').text
    temp['biliner'] = news.find('span' , {'class' : 'xBbh9'}).text
    temp['img'] = news.find('a').find('img')["src"]
    temp['link'] = "https://news.google.com" + news.find('h3').find('a')['href'][1:]
    temp['source'] = news.find('a', {'class' : 'wEwyrc AVN2gc uQIVzc Sksgp'}).text
    related_news.append(temp)

# %%
### Output related_news
print(related_news)
# Out:
# [{'title': 'No, boiled garlic water cannot cure coronavirus. The claim is false', 'biliner': 'In case you have come across messages which claim that patient infected with coronavirus can be cured with one bowl of freshly boiled garlic water, beware ...', 'img': 'https://lh4.googleusercontent.com/proxy/xvbFQ2zJxre_0Ea4jkeOJoyesL3m8aGd-EuuqTxlX9d1Ka1zHBA5UPV_UYMMsi5zU84hDRmFALozK1JEJS1KEGizpwlIrFxuy06PPWt5qzkf=-p-df-h100-w100', 'link': 'https://news.google....?hl=en-US&gl=US&ceid=US%3Aen', 'source': 'Hindustan Times'}, {'title': 'What was behind the Irish grá for garlic as a folk cure? Folklore', 'biliner': 'Whenever an epidemic has emerged, garlic has been one of the first preventive and curative remedies to be tried out.', 'img': 'https://lh6.googleusercontent.com/proxy/op2CX3My1Swyn9fwBfH4lUCLvEWK3SxIBStsDaQIDrUeiLVTsQKtj0JC7Vw5uDb3DC1coNPyVposUHrd1TL5oJoh=-p-df-h100-w100', 'link': 'https://news.google.com/articles/CBMiV2h0dHBzOi8vd3d3LnJ0ZS5pZS9icmFpbnN0b3JtLzIwMjAvMDUyMC8xMTM5NTM4LWdhcmxpYy1mb2xrbG9yZS1jdXJlcy1pbGxuZXNzLXBhbmRlbWljL9IBAA?hl=en-US&gl=US&ceid=US%3Aen', 'source': 'RTE.ie'}, {'title': "Garlic, sesame oil and UV lamps to treat coronavirus? Here's WHO you can trust!", 'biliner': 'Before you press that forward message on any viral coronavirus message from your family WhatsApp group, read these first!', 'img': 'https://lh3.googleusercontent.com/proxy/A10AKI60133tEJksybhh6P6FwSSw6O9ZuDurn-QM7gop5W7Ex3uDrW0TJnLkIxAS8TgB2M6hOUtRSiKnZdq-SodKH0YdE0wcMnpYkGVlIwRiOs9S8BMr4cRBzki1zc3VJnpN1f5M11Z77hkZWrPlXzhsZ_uPeOfYQ1tb2MRMvzFA=-p-df-h100-w100', 'link': 'https://news.google.?hl=en-US&gl=US&ceid=US%3Aen', 'source': 'The New Indian Express'}, {'title': 'From rumor to 2,000 deaths: How coronavirus outbreak unfolded for Americans at ground zero', 'biliner': 'Since emerging in late December, the coronavirus outbreak in Wuhan, China, has killed more than 2,000 people and infected tens of thousands more across the ...', 'img': 'https://lh3.googleusercontent.com/OSZAtJyRZ0s2HcKxWle7hA6XRd3qlTSqHfrIgnbCKME3B3-OE1QT5UDaPVqREhGZUAuhm9CIGts5gy7H-g=-p-df-h100-w100', 'link': 'https://news.google.com/articles/CAIiEOG-WBsHKNPqW2AlxgOUnBQqGQgEKhAIACoHCAowjsP7CjCSpPQCMKCK0wU?hl=en-US&gl=US&ceid=US%3Aen', 'source': 'USA TODAY'}, {'title': 'Home remedies for pneumonia: 12 ways to ease symptoms naturally', 'biliner': 'Some of the symptoms of pneumonia may be manageable at home. This article covers home remedies for pneumonia and when to see a doctor. Learn more ...', 'img': 'https://lh3.googleusercontent.com/proxy/WF5qkeal85basI1WH3D1o70yxMzUDq0uB7p-a3swbvXnTTQp24657tslWsuj26alYBEYIdKfsNYdI9dId7-N07XffBiJQSdToOhgQwyTzXAAjoEWevjOblVmw0d70zixIWVLYaxer5fAItpjrz7DPogy3IgXSucziRhtDcnudxZ8iywgP6lUUsH5bJWdioBP7VWnxe0qOdDWo33lC7iLbI4O=-p-df-h100-w100', 'link': 'https://news.google.com/articles/CBMiMGh0dHBzOi8vd3d3Lm1lZGljYWxuZXdzdG9kYXkuY29tL2FydGljbGVzLzMyMDg4MdIBAA?hl=en-US&gl=US&ceid=US%3Aen', 'source': 'Medical News Today'}, {'title': 'How to get your voice back: Tips and tricks', 'biliner': 'People may be able to get their voices back by gargling salt water, drinking fluids, or resting their voice. A doctor may also provide medications. Learn how to get ...', 'img': 'https://lh4.googleusercontent.com/proxy/1Xe2AdohBQLxExgIFEG9RjmNIEP0_jcac938d2aOZgx4S6kXvIyqjqnMzYWcvpOmbfJ6xG3CZzcUr8KwP6XgAQK4CrRq7Rk0XUSfzfG2raFPrXZ6il6bLF9DXa1sQF8IWUvmSOTE3pJkcevqu-m8lvqxL7j_ViKdwSm9BFiuTH35hUfQUsGMVOTLos6PoO7gBs5aQQLbGLpJxgSYlAm2lHY6V9-IIRJXdTK1=-p-df-h100-w100', 'link': 'https://news.google.com/articles/CBMiMGh0dHBzOi8vd3d3Lm1lZGljYWxuZXdzdG9kYXkuY29tL2FydGljbGVzLzMyNTc0 ...
